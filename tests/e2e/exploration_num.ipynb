# %% [markdown]
# # Field field1

# %% [markdown]
# ## Prepare data

# %% [markdown]
# ### Load libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
from pandas.io.json import json_normalize
data = pd.read_json('/home/leti/Git/machine-learning/ml-auto-explorer/ds/MarketingFakeJoinedData-v1.5.json')

# %% [markdown]
# ## General info

# %%
data.printSchema()

# %% [markdown]
# ###Field [field1] was detected as###numeric, so we perform some numeric exploration.

# %% [markdown]
# ### Generate this column dataframe

# %%
col_2 = 'field1'

# %% [markdown]
# ### Describe

# %%
data.describe([col_2]).show()

# %% [markdown]
# ### Type detection

# %%
data.schema[col_2]

# %% [markdown]
# ### Show first values

# %%
data.select([col_2]).show()

# %% [markdown]
# ### Null count

# %%
data.where((data[col_2].isNull()).count()

# %% [markdown]
# ### Show Empties

# %%
data.where((data[col_2]) == '').show()

# %% [markdown]
# ### Histogram

# %%
percentiles = []
for i in np.arange(0.0, 1.1, 0.1):
    percentiles.append(col_2.quantile(i))
plt.hist(col_2, percentiles)
